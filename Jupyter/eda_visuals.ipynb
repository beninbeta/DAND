# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the quiz questions below this notebook. Use the `winequality_edited.csv` dataset, which you should've created  in the previous concept: *Appending Data (cont.)*.

# %%
# Load dataset
import numpy as np
import pandas as pd
wp = pd.read_csv('winequality_edited.csv')
wp.head()
# Out:
#    alcohol  chlorides  citric_acid  color  density  fixed_acidity  \
# 0      8.8      0.045         0.36  white   1.0010            7.0
# 1      9.5      0.049         0.34  white   0.9940            6.3
# 2     10.1      0.050         0.40  white   0.9951            8.1
# 3      9.9      0.058         0.32  white   0.9956            7.2
# 4      9.9      0.058         0.32  white   0.9956            7.2
#
#    free_sulfur_dioxide    pH  quality  residual_sugar  sulphates  \
# 0                 45.0  3.00        6            20.7       0.45
# 1                 14.0  3.30        6             1.6       0.49
# 2                 30.0  3.26        6             6.9       0.44
# 3                 47.0  3.19        6             8.5       0.40
# 4                 47.0  3.19        6             8.5       0.40
#
#    total_sulfur_dioxide  volatile_acidity
# 0                 170.0              0.27
# 1                 132.0              0.30
# 2                  97.0              0.28
# ...

# %% [markdown]
# ### Histograms for Various Features

# %%
wp['fixed_acidity'].hist(figsize=(8,8));

# %%
wp['total_sulfur_dioxide'].hist(figsize=(8,8));

# %%
wp['pH'].hist(figsize=(8,8));

# %%
wp['alcohol'].hist(figsize=(8,8));

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %%
wp.plot(kind='scatter',x='quality',y='volatile_acidity')

# %%
wp.plot(kind='scatter', x='quality', y='residual_sugar')

# %%
wp.plot(kind='scatter', x='quality', y='pH')

# %%
wp.plot(kind='scatter',x='quality', y='alcohol')
