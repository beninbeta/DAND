# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below. Remember, you created this dataset at the bottom of the notebook in the "Reading CSV Files" section earlier in the lesson! Check your work with the solutions on that page if you are having trouble getting this dataset.

# %%
# import and load data
import pandas as pd
% matplotlib inline

ppd = pd.read_csv('powerplant_data_edited.csv')
ppd.head()
# Out:
#     Temp  Exhaust Vacuum  Pressure  Humidity  E_Output
# 0   8.34           40.77   1010.84     90.01    480.48
# 1  23.64           58.49   1011.40     74.20    445.75
# 2  29.74           56.90   1007.15     41.91    438.76
# 3  19.07           49.69   1007.22     76.79    453.09
# 4  11.80           40.66   1017.13     97.20    464.43

# %%
# plot relationship between temperature and electrical output
ppd.plot(x='Temp',y='E_Output', kind='scatter');

# %%
# plot distribution of humidity
ppd['Humidity'].plot('hist')

# %%
# plot box plots for each variable
ppd.plot(kind='box',figsize=(10,10));

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2e45a977026a> in <module>()
# ----> 1 ppd['Pressure'].value_counts().plot(kind='scatter');
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
# -> 1746                              % kind)
#    1747
#    1748     elif kind in _series_kinds:
#
# ValueError: plot kind 'scatter' can only be used for data frames
