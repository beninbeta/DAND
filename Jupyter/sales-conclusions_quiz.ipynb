# %% [markdown]
# # Drawing Conclusions Quiz
# Use the space below to explore `store_data.csv` to answer the quiz questions below.

# %%
# imports and load data
import pandas as pd
import matplotlib.pyplot as plot
% matplotlib inline
sd = pd.read_csv('store_data.csv', parse_dates=['week']).set_index('week')
sd.sort_values(by='week', ascending=False)
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2018-02-25    7560    6904    3569    5045    2585
# 2018-02-18    3512    7511    4151    5596    3501
# 2018-02-11    9202    3677    4540    6186     243
# 2018-02-04    4853    6503    4187    5956    1458
# 2018-01-28     282    6351    7759    5558    1028
# 2018-01-21    5553    3971    3761    6255    3071
# 2018-01-14    6963    4014    4215    7153    3097
# 2018-01-07    8978   11312    4158    5019    3842
# 2017-12-31   11875    1527    6711    5265    1701
# 2017-12-24    8976    9503    6240    3882    2890
# 2017-12-17    5310    8647    5680    7049    3578
# 2017-12-10    9348    5624    5446    5448     227
# 2017-12-03    5179    3850    6121    6778     113
# 2017-11-26    6866    5011    5401    4736    3232
# 2017-11-19    9960    8529    4501    7631     505
# 2017-11-12     137   12261    5455    7695    2599
# 2017-11-05   12785    1800    6163    5157     578
# ...

# %%
# explore data
g = sd.groupby(by=[sd.index.month, sd.index.year])

# %%
# total sales for the last month
g.sum()
# Out:
#            storeA  storeB  storeC  storeD  storeE
# week week
# 1    2015   20667   24797   19770   27199   12346
#      2016   22270   35665   23753   22344   15218
#      2017   24329   43379   25452   26658   19399
#      2018   21776   25648   19893   23985   11038
# 2    2015   19593   16458   19832   21621   10220
#      2016   18714   28947   23476   19666   14341
#      2017   27434   23637   23011   22981   12327
#      2018   25127   24595   16447   22783    7787
# 3    2015   40155   56675   30601   28309   17700
#      2016   22557   22172   17828   21288   10322
#      2017   29550   21035   24881   20148    8245
# 4    2015    8626   22906   19270   25630   12776
#      2016   33367   37925   18497   19335   12926
#      2017   35978   28727   22852   23545   11263
# 5    2014   24693   27285   22044   24833    9886
#      2015   18762   51574   24974   30044   19846
#      2016   26775   33040   22987   30235   13018
#      2017   20681   26669   20635   24155   16929
# ...

# %%
# average sales
sd.describe()
# Out:
#              storeA        storeB       storeC       storeD       storeE
# count    200.000000    200.000000   200.000000   200.000000   200.000000
# mean    5865.480000   6756.710000  4942.105000  5431.405000  2580.025000
# std     2958.230318   3601.339489  1325.407768  1183.111323  1725.651381
# min      137.000000     14.000000   927.000000  2276.000000    39.000000
# 25%     3812.250000   3884.500000  4053.500000  4717.000000  1235.000000
# 50%     5713.500000   6771.000000  4962.500000  5382.000000  2522.000000
# 75%     7662.250000   9350.500000  5801.750000  6243.750000  3574.250000
# max    14403.000000  15841.000000  8293.000000  8190.000000  7553.000000

# %%
# sales on march 13, 2016
ms = sd[sd.index == '2016-03-13']
ms.head()
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2016-03-13    2054    1390    5112    5513    2536

# %%
# worst week for store C
sd.sort_values(by='storeC')
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2014-07-06    8567    3228     927    3277     168
# 2016-01-24    3858    7424    2036    4079    5119
# 2014-07-20    5299    5456    2104    3889    2429
# 2017-10-01    9522   11753    2286    6991     188
# 2017-02-12    7629    5696    2332    6543    3143
# 2014-08-24     576    9082    2411    4856    1408
# 2015-10-04    2245   10436    2444    4714    1400
# 2017-06-11    2648     882    2460    6305    4069
# 2014-08-10    5715   13234    2476    5265    4900
# 2017-06-04     903    8402    2595    3712    3932
# 2014-10-26    4319    3648    2878    7236    3067
# 2014-12-28    8605    6624    2932    3488    2647
# 2015-05-17    3697   15841    2972    8190    3235
# 2016-09-25    5551   10100    3046    5215    1609
# 2017-08-27    3103   10565    3049    6339    6585
# 2016-10-02    4234    3622    3049    3843    1894
# 2017-05-07     929    5059    3083    6122    3167
# ...

# %%
# total sales during most recent 3 month period
mon_sum = sd.resample('M').sum()
mon_sum.tail(3).sum()
#last_3 = mon_sum.groupby('week').tail(3)
# Out:
# storeA    87591
# storeB    79394
# storeC    66538
# storeD    75190
# storeE    27334
# dtype: int64
